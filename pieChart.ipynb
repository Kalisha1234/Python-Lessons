# %% [markdown]
# <a href="https://colab.research.google.com/github/Kalisha1234/Python-Lessons/blob/main/pieChart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pie chart with Matplotlip

# %%
#importing matplotlib
import matplotlib.pyplot as plt

# %%
# defining proteins and sizes
labels = ['Meat', 'Beef', 'Sausage', 'Egg', 'FIsh']
size = [20, 15, 15, 35, 10, 15]

# %%
plt.figure(figsize=(10,10))
plt.pie(size, labels=labels, autopct='%1.1f%%')
plt
plt.show()
